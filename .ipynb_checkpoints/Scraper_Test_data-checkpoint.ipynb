# %% [markdown]
# # Test Dataset Scraping and Cleaning
#
# In this notebook, we pull the test dataset from the New York Times interviews of the Democratic Candidates. We will also be pulling a Trump tweet dataset to see an example of views on the other end of the political spectrum. After running scrape_test, we manually delete the beginning and ending rows in the output CSV that correspond to formatting. The next function, address_short_strings, puts strings smaller than 50 characters into the previous row to provide additional context. This result goes in cavndidatename_cleaned.csv (raw data is in candidate.csv)
#
# Note that we may consolidate all the rows into one single record for testing. That is an option we can run at testing time. We may opt to run each of these records separately and do post processing to get the maximum value for a label over all records for a given candidate (since not all rows will contain information about all issues). This may help with ensuring models such as RNNs do not "forget" about certain topics in earlier sections of the passage.

# %%
from bs4 import BeautifulSoup
import requests
import numpy as np
import pandas as pd

def scrape_test(candidate, url):
    headers = requests.utils.default_headers()
    headers.update({ 'User-Agent': 'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:52.0) Gecko/20100101 Firefox/52.0'})
    
    texts = []
    req = requests.get(url, headers)
    soup = BeautifulSoup(req.content, 'html.parser')
    
    s = soup.get_text()
    all_strings = s.split("\n")
    body = [string for string in all_strings if len(string) > 0]
    texts.extend(body)
    
    
    df = pd.DataFrame(texts, columns = ['text']) 
    print(df.head())
    df.to_csv(candidate + ".csv")

# %%
scrape_test("Biden", "https://www.nytimes.com/interactive/2020/01/17/opinion/joe-biden-nytimes-interview.html")
# Out:
#                                                 text
# 0  Opinion | Joe Biden Says Age Is Just a Number ...
# 1                  [data-timezone] { display: none }
# 2  .css-6n7j50{display:inline;}.css-1kj7lfb{displ...
# 3                                        // 20.546kB
# 4                  window.viHeadScriptSize = 20.546;

# %%
scrape_test("Sanders", "https://www.nytimes.com/interactive/2020/01/13/opinion/bernie-sanders-nytimes-interview.html")
# Out:
#                                                 text
# 0  Opinion | Bernie Sanders Wants to Change Your ...
# 1                  [data-timezone] { display: none }
# 2  .css-6n7j50{display:inline;}.css-1kj7lfb{displ...
# 3                                        // 20.546kB
# 4                  window.viHeadScriptSize = 20.546;

# %%
scrape_test("Buttigieg", "https://www.nytimes.com/interactive/2020/01/16/opinion/pete-buttigieg-nytimes-interview.html")
# Out:
#                                                 text
# 0  Opinion | Pete Buttigieg Says He’s More Than a...
# 1                  [data-timezone] { display: none }
# 2  .css-6n7j50{display:inline;}.css-1kj7lfb{displ...
# 3                                        // 20.546kB
# 4                  window.viHeadScriptSize = 20.546;

# %%
scrape_test("Klobuchar", "https://www.nytimes.com/interactive/2020/01/15/opinion/amy-klobuchar-nytimes-interview.html")
# Out:
#                                                 text
# 0  Opinion | Amy Klobuchar on Plans vs. Pipe Drea...
# 1                  [data-timezone] { display: none }
# 2  .css-6n7j50{display:inline;}.css-1kj7lfb{displ...
# 3                                        // 20.546kB
# 4                  window.viHeadScriptSize = 20.546;

# %%
scrape_test("Yang", "https://www.nytimes.com/interactive/2020/01/15/opinion/andrew-yang-nytimes-interview.html")
# Out:
#                                                 text
# 0  Opinion | Andrew Yang Is Listening - The New Y...
# 1                  [data-timezone] { display: none }
# 2  .css-6n7j50{display:inline;}.css-1kj7lfb{displ...
# 3                                        // 20.546kB
# 4                  window.viHeadScriptSize = 20.546;

# %%
scrape_test("Warren", "https://www.nytimes.com/interactive/2020/01/14/opinion/elizabeth-warren-nytimes-interview.html")
# Out:
#                                                 text
# 0  Opinion | Elizabeth Warren Is Ready for a Figh...
# 1                  [data-timezone] { display: none }
# 2  .css-6n7j50{display:inline;}.css-1kj7lfb{displ...
# 3                                        // 20.546kB
# 4                  window.viHeadScriptSize = 20.546;

# %%
def address_short_strings(candidate):
    df = pd.read_csv(candidate + ".csv")
    last_valid_row = 0
    for index, row in df.iterrows():
        if index > 0 and len(row.text) < 50:
            print(index, last_valid_row)
            df.at[last_valid_row,'text'] = df.loc[last_valid_row]["text"] + ' ' + row.text
            df.drop(index, inplace=True)
        else:
            last_valid_row = index
    df = df[["text"]]
    df.to_csv(candidate + "_cleaned.csv")
    return(df)

# %%
address_short_strings("Biden")
# Out:
# 4 3
# 13 12
# 17 16
# 19 18
# 30 29
# 40 39
# 41 39
# 54 53
# 57 56
# 62 61
# 67 66
# 70 69
# 72 71
# 73 71
# 74 71
# 94 93
# 98 97
# 102 101
# 103 101
# 104 101
# 106 105
# 109 108
# 110 108
# 111 108
# 118 117
# 119 117
# 123 122
# 124 122
# 125 122
# 126 122
# 134 133
# 135 133
# 137 136
# 138 136
# 139 136
# 143 142
# 144 142
# 145 142
# 155 154
# 156 154
# 157 154
# 159 158
# 161 160
# 168 167
# 175 174
# 176 174
# 181 180
# 182 180
# 187 186
# 190 189
# 193 192
# 194 192
# 195 192
# 199 198
# 200 198
# 201 198
# 204 203
# 209 208
# 212 211
# 213 211
# 220 219
# 233 232
# 242 241
# 245 244
# 246 244
# 249 248
# 257 256
# 259 258
# 261 260
# 262 260
# 266 265
# 267 265
# 268 265
# 269 265
# 286 285
# 287 285
# 288 285
# 292 291
# 297 296
# 306 305
# 307 305
# 310 309
# 311 309
# 316 315
# 328 327
# 336 335
# 337 335
# 338 335
# 347 346
# 351 350
# 354 353
# 355 353
# 358 357
# 367 366
# 368 366
# 378 377
# 380 379
# 385 384
# 390 389
# 394 393
# 399 398
# 403 402
# 406 405
# 417 416
# 420 419
# 443 442
# 447 446
# 458 457
# 465 464
# 466 464
# 471 470
# 473 472
# 475 474
# 476 474
# 489 488
# 525 524
# 531 530
# 532 530
# 533 530
# 536 535
# 539 538
# 540 538
# 541 538
# 543 542
# 544 542
#                                                   text
# 0    Opinion | Joe Biden Says Age Is Just a Number ...
# 1    He also discussed the “creeps” in Silicon Vall...
# 2    Here is a transcript, with annotations in blue...
# 3    Kathleen Kingsbury: So Mr. Vice President, we’...
# 5    KK: We have a lot of questions to get through,...
# 6    In the October Democratic debate, Mr. Biden wa...
# 7    Look, I fought corruption when I was in Ukrain...
# 8    The Times editorial board wrote in 2015: “It s...
# 9    He’s acknowledged that he thought it was a mis...
# 10   KK: Would you be in favor of a law banning the...
# 11   The answer is, I hadn’t thought of it that way...
# 12   Look, as I said, looking back on it, Hunter ha...
# 14   Well, the first lady will have an office, but ...
# 15   The first lady, since at least the Carter admi...
# 16       Watch a special endorsement episode of “Th...
# 18             This video excerpt has been edited b...
# 20   Mara Gay: Mr. Vice President, why don’t you su...
# 21   In the September Democratic debate, Mr. Biden ...
# 22   Well, I do support reparations for black Ameri...
# 23   Other candidates (and former candidates) in th...
# 24   The first thing I did as a young councilman an...
# 25   Mr. Biden ran for New Castle County Council in...
# 26   In the meantime, there’s a lot we have to do r...
# 27   MG: I’m just going to drill down a little bit ...
# 28   In the September Democratic debate, Mr. Biden ...
# 29   Well, I think you’re taking that out of contex...
# 31   No, well, O.K. The idea is that the responsibi...
# 32   I remember how much trouble Barack got in when...
# 33   Mr. Obama drew ire for a June 2008 speech at a...
# 34   What I found was that if, in fact, the people ...
# ..                                                 ...
# 506  And they were talking about how we had to make...
# 507  I look down at one guy and said, because your ...
# 508  But guess what? All white guys are just basica...
# 509  The second thing I said, I said and, by the wa...
# 510  Third thing I said, I said any man who raises ...
# 511  And then I talked about economic issues, about...
# 512  The other thing we think about, we think that ...
# 513  One of the things I did — now, I’m serious. Lo...
# 514  After Detroit filed the country’s largest ever...
# 515  But then we found out when it got out of bankr...
# 516  So I had an idea. We went to this outfit that ...
# 517  And on the floor I go around, my liberal frien...
# 518  You think people are stupid. Went to school wi...
# 519  He said, “What you doing, Joey?” And I remembe...
# 520  I said, “Well, how’s Tony doing?” His son was ...
# 521  They know it. They’re not stupid. We treat the...
# 522  That’s why I’m spending so much time with unio...
# 523  I can go down the list. Same with agriculture....
# 524  Guys, think about it, this is complicated stuf...
# 526  No, you do. I don’t mean that, but look what w...
# 527  KK: Speaking of which, we do actually have to ...
# 528  But again, I don’t think it’s talking down to ...
# 529  I’m just saying generically, think about the p...
# 530  I’m probably in real trouble after this interv...
# 534  BS: I’m from Chester, Pa., by the way. Right a...
# 535  Well, you know, and by the way, you know we ta...
# 537  That’s right, you understand it. I’m not jokin...
# 538  According to the Centers for Disease Control, ...
# 542  I love the lectures I get about — do you under...
# 545  Correction: An earlier version of this annotat...
#
# [421 rows x 1 columns]

# %%
address_short_strings("Sanders")
address_short_strings("Buttigieg")
address_short_strings("Klobuchar")
address_short_strings("Yang")
address_short_strings("Warren")
# Out:
# 7 6
# 19 18
# 21 20
# 23 22
# 31 30
# 33 32
# 35 34
# 36 34
# 38 37
# 49 48
# 59 58
# 63 62
# 65 64
# 68 67
# 73 72
# 83 82
# 112 111
# 115 114
# 116 114
# 117 114
# 122 121
# 124 123
# 135 134
# 139 138
# 144 143
# 147 146
# 150 149
# 151 149
# 155 154
# 156 154
# 158 157
# 163 162
# 168 167
# 172 171
# 178 177
# 179 177
# 184 183
# 185 183
# 186 183
# 191 190
# 192 190
# 211 210
# 215 214
# 231 230
# 232 230
# 236 235
# 252 251
# 253 251
# 269 268
# 276 275
# 283 282
# 285 284
# 286 284
# 287 284
# 288 284
# 289 284
# 291 290
# 299 298
# 304 303
# 308 307
# 309 307
# 310 307
# 311 307
# 314 313
# 315 313
# 322 321
# 323 321
# 324 321
# 325 321
# 339 338
# 350 349
# 351 349
# 357 356
# 358 356
# 359 356
# 365 364
# 369 368
# 372 371
# 384 383
# 385 383
# 387 386
# 392 391
# 394 393
# 395 393
# 397 396
# 398 396
# 399 396
# 400 396
# 402 401
# 409 408
# 3 2
# 236 235
# 237 235
# 239 238
# 240 238
# 250 249
# 251 249
# 266 265
# 267 265
# 270 269
# 272 271
# 279 278
# 280 278
# 281 278
# 286 285
# 291 290
# 292 290
# 303 302
# 308 307
# 317 316
# 318 316
# 320 319
# 322 321
# 324 323
# 329 328
# 333 332
# 345 344
# 346 344
# 351 350
# 356 355
# 359 358
# 360 358
# 361 358
# 372 371
# 376 375
# 382 381
#                                                   text
# 0    Opinion | Elizabeth Warren Is Ready for a Figh...
# 1    Elizabeth Warren, in her interview with the Ti...
# 2    But a few questions caught her off guard: how ...
# 3    Here is a transcript, with annotations in blue...
# 4    Kathleen Kingsbury: So we don’t have very much...
# 6    KK: Should it be against the law for the child...
# 7    Several members of the Trump family have come ...
# 8    You know, when I put together my anti-corrupti...
# 9    Senator Warren’s anti-corruption plan includes...
# 11   Yes. I just think it’s got this — no one has t...
# 12   KK: So do you think that Vice President Biden ...
# 13   I’m not going to do this. I’m just not. I’m no...
# 14   Some of the Democratic candidates have been mo...
# 15   KK: Well, we’re going to start, if you don’t m...
# 17       Watch a special endorsement episode of “Th...
# 19             This video excerpt has been edited b...
# 21   KK: Throughout America, many jobs that were on...
# 22   Over several decades, it’s become increasingly...
# 23   I think having people here who are working und...
# 24   KK: But does it drive down wages for American ...
# 25   Well, it’s not good for them and in a dozen di...
# 26   KK: But do you know of any specific evidence t...
# 27   No. I thought you were talking about undocumen...
# 28   KK: Yes, I am, undocumented immigrants, excuse...
# 29   So whenever people are being paid outside the ...
# 30   KK: We have some foreign policy questions for ...
# 31   Serge Schmemann: Let me ask you about the Midd...
# 32   I think we need to get our combat troops out. ...
# 33   After Senator Warren said during the October d...
# 34   SS: So you mean getting rid of the combat troo...
# ..                                                 ...
# 343  But it’s not going to be real change because s...
# 344  BS: Last question. What are you likely to fail...
# 347  Yeah, I can imagine. Nobody ever wants to answ...
# 348  But I take your question seriously. The place ...
# 349  I know that as you sit here it looks like, wow...
# 350  The Times columnist David Leonhardt wrote in S...
# 352  But a degree worse, two degrees worse. I watch...
# 353  When I was a girl, you had a better than 50/50...
# 354  The tension between incremental and transforma...
# 355  NF: How do you deal with the fact that while p...
# 357  NF: In the last month or so, your — I know you...
# 358  I don’t know anybody who’s afraid of the 2-cen...
# 362  O.K.? And I have seen the billionaire go on TV...
# 363  NF: But it’s also about the “Medicare for all”...
# 364  But that is the specific, right? This is the p...
# 365  You do what you can with 50 votes to offer peo...
# 366  But I get it. There are right now, Democrats a...
# 367  “Medicare for all” has created deep divisions ...
# 368  We’re going to have that party who lost a bunc...
# 369  And I know it’s tough between here and there. ...
# 370  In 2012, Massachusetts Democrats, worried abou...
# 371  And so when somebody — when I was first thinki...
# 373  Among other things, right? And it’s why though...
# 374  Critics of the wealth tax point out that only ...
# 375  Think of what that means. Do — you know that t...
# 377  Exactly. A 2-cent wealth tax just means if you...
# 378  In a democracy, how is it that they have so mu...
# 379  These are the fights we need to have. These ar...
# 380  I am in this fight because my daddy ended up a...
# 381  KK: O.K., Kristen’s going to kill me, but than...
#
# [304 rows x 1 columns]
